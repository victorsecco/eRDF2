# %%
import pandas as pd

# Define the data
data = {
    "Parameter": [
        "Lattice constant a",
        "Lattice constant c",
        "z value Zn",
        "B value",
        "Stacking fault property",
        "Diameter in ab plane",
        "Diameter along c-axis",
        "Quadratic correlation term",
        "Linear correlation term",
        "Qbroadening (Qalpha)",
        "Qdamping (QSIG)",
        "PDF scale factor",
    ],
    "z-CdSe": [
        "0.4301528677E+01",
        "0.6981561461E+01",
        "0.3716046330E+00",
        "0.2391347247E+01",
        "0.2459684095E+00",
        "0.4414645524E+02",
        "0.3993219260E+02",
        "0.0000000000E+00",
        "0.1437193676E+00",
        "0.5444356349E-02",
        "0.4923087512E-01",
        "0.5543040093E+00",
    ],
}

data["z-CdSe"] = [
    f"{float(value):.3e}" for value in data["z-CdSe"]
]


# Convert to DataFrame
df = pd.DataFrame(data)

df.style.set_table_styles(
    [{'selector': 'thead th', 'props': [('font-size', '14pt')]},
     {'selector': 'tbody td', 'props': [('border', '1px solid black')]}]
)
# Out:
# <style type="text/css">
# #T_da723 thead th {
#   font-size: 14pt;
# }
# #T_da723 tbody td {
#   border: 1px solid black;
# }
# </style>
# <table id="T_da723">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da723_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_da723_level0_col1" class="col_heading level0 col1" >z-CdSe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da723_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da723_row0_col0" class="data row0 col0" >Lattice constant a</td>
#       <td id="T_da723_row0_col1" class="data row0 col1" >4.302e+00</td>
#     </tr>
#     <tr>
#       <th id="T_da723_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da723_row1_col0" class="data row1 col0" >Lattice constant c</td>
#       <td id="T_da723_row1_col1" class="data row1 col1" >6.982e+00</td>
#     </tr>
#     <tr>
# ...
